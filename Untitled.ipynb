# %%
import scipy.stats as stats
import matplotlib.pyplot as plt, mpld3
import wfBm
values1 = wfBm.wfBm()
fig_size = [8,4]
plt.rcParams["figure.figsize"] = fig_size
print(len(values1))
# Out:
# 2

# %%
# %matplotlib inline
mpld3.enable_notebook()
# Out:
# /Users/shoesh/anaconda/lib/python3.5/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /Users/shoesh/anaconda/lib/python3.5/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /Users/shoesh/anaconda/lib/python3.5/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /Users/shoesh/anaconda/lib/python3.5/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /Users/shoesh/anaconda/lib/python3.5/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /Users/shoesh/anaconda/lib/python3.5/site-packages/ipykernel/pylab/config.py:44: DeprecationWarning: InlineBackend._config_changed is deprecated: use @observe and @unobserve instead.
#   def _config_changed(self, name, old, new):
# /Users/shoesh/anaconda/lib/python3.5/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)
# /Users/shoesh/anaconda/lib/python3.5/site-packages/IPython/core/formatters.py:96: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /Users/shoesh/anaconda/lib/python3.5/site-packages/IPython/core/formatters.py:675: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# /Users/shoesh/anaconda/lib/python3.5/site-packages/IPython/core/formatters.py:667: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /Users/shoesh/anaconda/lib/python3.5/site-packages/IPython/core/formatters.py:670: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /Users/shoesh/anaconda/lib/python3.5/site-packages/IPython/core/formatters.py:670: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /Users/shoesh/anaconda/lib/python3.5/site-packages/IPython/core/formatters.py:675: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):

# %%
# %load_ext autoreload
# %autoreload

# %%
# Out:
# [-0.72682933908347702, 1, 0.70968558297945528, 0]
# -0.310525579899
# <style>
#
# </style>
#
# <div id="fig_el109545556619445421996553"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el109545556619445421996553", {"width": 640.0, "plugins": [{"type": "reset"}, {"type": "zoom", "enabled": false, "button": true}, {"type": "boxzoom", "enabled": false, "button": true}], "axes": [{"texts": [], "collections": [{"zorder": 2, "xindex": 0, "alphas": [1.0], "offsetcoordinates": "display", "id": "el10954549654176", "yindex": 1, "offsets": "data01", "paths": [[[[0.0, 1.0], [0.00546448087431694, 0.9820193599158586]], ["M", "L"]], [[[0.00546448087431694, 0.9820193599158586], [0.01092896174863388, 0.9640387198317173]], ["M", "L"]], [[[0.01092896174863388, 0.9640387198317173], [0.01639344262295082, 0.9460580797475759]], ["M", "L"]], [[[0.01639344262295082, 0.9460580797475759], [0.02185792349726776, 0.9453376071930566]], ["M", "L"]], [[[0.02185792349726776, 0.9453376071930566], [0.027322404371584702, 0.9446171346385374]], ["M", "L"]], [[[0.027322404371584702, 0.9446171346385374], [0.03278688524590164, 0.943896662084018]], ["M", "L"]], [[[0.03278688524590164, 0.943896662084018], [0.03825136612021858, 0.8473821150210615]], ["M", "L"]], [[[0.03825136612021858, 0.8473821150210615], [0.04371584699453552, 0.750867567958105]], ["M", "L"]], [[[0.04371584699453552, 0.750867567958105], [0.04918032786885246, 0.6543530208951486]], ["M", "L"]], [[[0.04918032786885246, 0.6543530208951486], [0.0546448087431694, 0.6767075450080235]], ["M", "L"]], [[[0.0546448087431694, 0.6767075450080235], [0.06010928961748634, 0.6990620691208984]], ["M", "L"]], [[[0.06010928961748634, 0.6990620691208984], [0.06557377049180328, 0.7214165932337734]], ["M", "L"]], [[[0.06557377049180328, 0.7214165932337734], [0.07103825136612021, 0.7220129294335031]], ["M", "L"]], [[[0.07103825136612021, 0.7220129294335031], [0.07650273224043716, 0.722609265633233]], ["M", "L"]], [[[0.07650273224043716, 0.722609265633233], [0.08196721311475409, 0.7232056018329628]], ["M", "L"]], [[[0.08196721311475409, 0.7232056018329628], [0.08743169398907104, 0.7630682786197206]], ["M", "L"]], [[[0.08743169398907104, 0.7630682786197206], [0.09289617486338797, 0.8029309554064784]], ["M", "L"]], [[[0.09289617486338797, 0.8029309554064784], [0.09836065573770492, 0.8427936321932362]], ["M", "L"]], [[[0.09836065573770492, 0.8427936321932362], [0.10382513661202186, 0.7659255846497212]], ["M", "L"]], [[[0.10382513661202186, 0.7659255846497212], [0.1092896174863388, 0.6890575371062062]], ["M", "L"]], [[[0.1092896174863388, 0.6890575371062062], [0.11475409836065574, 0.6121894895626911]], ["M", "L"]], [[[0.11475409836065574, 0.6121894895626911], [0.12021857923497269, 0.6198877235755299]], ["M", "L"]], [[[0.12021857923497269, 0.6198877235755299], [0.12568306010928962, 0.6275859575883685]], ["M", "L"]], [[[0.12568306010928962, 0.6275859575883685], [0.13114754098360656, 0.6352841916012073]], ["M", "L"]], [[[0.13114754098360656, 0.6352841916012073], [0.1366120218579235, 0.5832201647218859]], ["M", "L"]], [[[0.1366120218579235, 0.5832201647218859], [0.14207650273224043, 0.5311561378425644]], ["M", "L"]], [[[0.14207650273224043, 0.5311561378425644], [0.14754098360655737, 0.479092110963243]], ["M", "L"]], [[[0.14754098360655737, 0.479092110963243], [0.15300546448087432, 0.5240388596384744]], ["M", "L"]], [[[0.15300546448087432, 0.5240388596384744], [0.15846994535519124, 0.5689856083137057]], ["M", "L"]], [[[0.15846994535519124, 0.5689856083137057], [0.16393442622950818, 0.6139323569889371]], ["M", "L"]], [[[0.16393442622950818, 0.6139323569889371], [0.16939890710382513, 0.5904181340071981]], ["M", "L"]], [[[0.16939890710382513, 0.5904181340071981], [0.17486338797814208, 0.5669039110254592]], ["M", "L"]], [[[0.17486338797814208, 0.5669039110254592], [0.18032786885245902, 0.5433896880437202]], ["M", "L"]], [[[0.18032786885245902, 0.5433896880437202], [0.18579234972677597, 0.5617642225596894]], ["M", "L"]], [[[0.18579234972677597, 0.5617642225596894], [0.1912568306010929, 0.5801387570756587]], ["M", "L"]], [[[0.1912568306010929, 0.5801387570756587], [0.19672131147540983, 0.598513 ...

# %%
import wfBm
a = []
values1 = wfBm.wfBm()
i = 0
while i < 200:
    i += 1
    a.append(abs(max(values1) - min(values1)))
    values1 = wfBm.wfBm()
n, bins, patches = plt.hist(a, 20)
plt.plot(bins)
# plt.show()
print(wfBm.H)
mpld3.display()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-ec6e564efde4> in <module>()
#       5 while i < 200:
#       6     i += 1
# ----> 7     a.append(abs(max(values1) - min(values1)))
#       8     values1 = wfBm.wfBm()
#       9 n, bins, patches = plt.hist(a, 20)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.collections as mcoll
import matplotlib.path as mpath

def colorline(
    x, y, z=None, cmap=plt.get_cmap('copper'), norm=plt.Normalize(0.0, 1.0),
        linewidth=3, alpha=1.0):
    """
    http://nbviewer.ipython.org/github/dpsanders/matplotlib-examples/blob/master/colorline.ipynb
    http://matplotlib.org/examples/pylab_examples/multicolored_line.html
    Plot a colored line with coordinates x and y
    Optionally specify colors in the array z
    Optionally specify a colormap, a norm function and a line width
    """

    # Default colors equally spaced on [0,1]:
    if z is None:
        z = np.linspace(0.0, 1.0, len(x))

    # Special case if a single number:
    if not hasattr(z, "__iter__"):  # to check for numerical input -- this is a hack
        z = np.array([z])

    z = np.asarray(z)

    segments = make_segments(x, y)
    lc = mcoll.LineCollection(segments, array=z, cmap=cmap, norm=norm,
                              linewidth=linewidth, alpha=alpha)

    ax = plt.gca()
    ax.add_collection(lc)

    return lc

# %%
def make_segments(x, y):
    """
    Create list of line segments from x and y coordinates, in the correct format
    for LineCollection: an array of the form numlines x (points per line) x 2 (x
    and y) array
    """

    points = np.array([x, y]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    return segments

# %%
plt.rcParams["figure.figsize"]
# Out:
# /Users/shoesh/anaconda/lib/python3.5/site-packages/IPython/core/formatters.py:90: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /Users/shoesh/anaconda/lib/python3.5/site-packages/IPython/core/formatters.py:667: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# [6.0, 4.0]

# %%
from imp import reload
reload(wfBm)
# Out:
# <module 'wfBm' from '/Users/shoesh/Dropbox/sketches/wfBm.py'>

# %%
from imp import reload

# %%
reload(wfBm)
# Out:
# <module 'wfBm' from '/Users/shoesh/Dropbox/sketches/wfBm.py'>

# %%
wfBm.H
# Out:
# 0.9

# %%
corrs = []
corr = 1
v1 = []
v2 = []
last1 = 0
last2 = 0
for i in [-0.7,-0.7]:
    corr_bm = wfBm.wfBm(30,.8,i)
    corrs.append(stats.pearsonr(corr_bm[0], corr_bm[1])[0])
#     if i >= 1:
#         while corr < -0.9 or corr > -0.7:
#             values1 = wfBm.wfBm()
#             values2 = wfBm.wfBm()
#             corr, p = stats.pearsonr(values1, values2)
#     elif i < 1:
#         while corr < 0.7 or corr > 0.9:
#             values1 = wfBm.wfBm()
#             values2 = wfBm.wfBm()
#             corr, p = stats.pearsonr(values1, values2)
    first1 = corr_bm[0][0]
    first2 = corr_bm[1][0]
    shift1 = last1 - first1
    shift2 = last2 - first2
    values1 = [v + shift1 for v in corr_bm[0]]
    values2 = [v + shift2 for v in corr_bm[1]]
    v1.extend(values1)
    v2.extend(values2)
    last1 = values1[-1]
    last2 = values2[-1]
    corrs.append(corr)
    corr = 0
    
print(corrs)
corrOverall, p = stats.pearsonr(v1, v2)
print(corrOverall)
maxV = max([max(v1), max(v2)])
minV = min([min(v1), min(v2)])

t = [i for i in range(len(v1))]
t = list(map(lambda x, r=float(max(t) - min(t)): (x - min(t)) / r, t))
v1 = list(map(lambda x, r=float(max(v1) - min(v1)): (x - min(v1)) / r, v1))
v2 = list(map(lambda x, r=float(max(v2) - min(v2)): (x - min(v2)) / r, v2))

plt2 = plt.subplot2grid((2,4), (0,0), colspan=2)
path = mpath.Path(np.column_stack([t, v1]))
verts = path.interpolated(steps=3).vertices
tt, vv1 = verts[:, 0], verts[:, 1]
z = np.linspace(0, 1, len(vv1))
colorline(tt, vv1, z, cmap=plt.get_cmap('jet'), linewidth=2)

plt3 = plt.subplot2grid((2,4), (1, 0), colspan=2)
path = mpath.Path(np.column_stack([t, v2]))
verts = path.interpolated(steps=3).vertices
tt, vv2 = verts[:, 0], verts[:, 1]
z = np.linspace(0, 1, len(vv2))
colorline(tt, vv2, z, cmap=plt.get_cmap('jet'), linewidth=2)

plt1 = plt.subplot2grid((2,4), (0,2), rowspan=2, colspan=2)
path = mpath.Path(np.column_stack([v1, v2]))
verts = path.interpolated(steps=3).vertices
v1,v2 = verts[:, 0], verts[:, 1]
z = np.linspace(0, 1, len(v1))
colorline(v1, v2, z, cmap=plt.get_cmap('jet'), linewidth=2)

plt.tight_layout()
# plt.title('fBm (blue) vs BM (red)')
# plt.xlabel('i')
# plt.ylabel('x(i)')
# plt.scatter(v1,v2)
# plt.plot(v1,v2)
mpld3.display()
# Out:
# [0.74535621774713701, 1, -0.74262354358504146, 0]
# 0.325565054168
# <style>
#
# </style>
#
# <div id="fig_el151245385833607394557236"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el151245385833607394557236", {"plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}], "axes": [{"sharex": [], "zoomable": true, "xscale": "linear", "xlim": [0.0, 1.0], "texts": [], "sharey": [], "images": [], "ydomain": [0.0, 1.0], "paths": [], "ylim": [0.0, 1.0], "id": "el15124538650920", "axesbgalpha": null, "collections": [{"pathtransforms": [], "offsets": "data01", "paths": [[[[0.0, 1.0], [0.00546448087431694, 0.9860512888501943]], ["M", "L"]], [[[0.00546448087431694, 0.9860512888501943], [0.01092896174863388, 0.9721025777003887]],